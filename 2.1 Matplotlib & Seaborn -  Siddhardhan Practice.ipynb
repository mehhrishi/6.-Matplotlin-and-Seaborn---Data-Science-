# %% [markdown]
# #### Matplotlib in python
#  - useful for making plot
#
# Lets see how we can import matplotlib library:

# %%
# importing matplotlib Library 
import matplotlib.pyplot as plt
# import numpy to get data for our plots
import numpy as np

# %%
x = np.linspace(0,10,100)
y = np.sin(x)
z = np.cos(x)

# %%
print(x)
# will get evenly Spaced 100 values
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
# ...

# %%
print(y)
# Out:
# [ 0.          0.10083842  0.20064886  0.2984138   0.39313661  0.48385164
#   0.56963411  0.64960951  0.72296256  0.78894546  0.84688556  0.8961922
#   0.93636273  0.96698762  0.98775469  0.99845223  0.99897117  0.98930624
#   0.96955595  0.93992165  0.90070545  0.85230712  0.79522006  0.73002623
#   0.65739025  0.57805259  0.49282204  0.40256749  0.30820902  0.21070855
#   0.11106004  0.01027934 -0.09060615 -0.19056796 -0.28858706 -0.38366419
#  -0.47483011 -0.56115544 -0.64176014 -0.7158225  -0.7825875  -0.84137452
#  -0.89158426 -0.93270486 -0.96431712 -0.98609877 -0.99782778 -0.99938456
#  -0.99075324 -0.97202182 -0.94338126 -0.90512352 -0.85763861 -0.80141062
#  -0.73701276 -0.66510151 -0.58640998 -0.50174037 -0.41195583 -0.31797166
#  -0.22074597 -0.12126992 -0.0205576   0.0803643   0.18046693  0.27872982
#   0.37415123  0.46575841  0.55261747  0.63384295  0.7086068   0.77614685
#   0.83577457  0.8868821   0.92894843  0.96154471  0.98433866  0.99709789
# ...

# %%
print(z)
# Out:
# [ 1.          0.99490282  0.97966323  0.95443659  0.91948007  0.87515004
#   0.8218984   0.76026803  0.69088721  0.61446323  0.53177518  0.44366602
#   0.35103397  0.25482335  0.15601496  0.0556161  -0.04534973 -0.14585325
#  -0.24486989 -0.34139023 -0.43443032 -0.52304166 -0.60632092 -0.68341913
#  -0.75355031 -0.81599952 -0.87013012 -0.91539031 -0.95131866 -0.97754893
#  -0.9938137  -0.99994717 -0.9958868  -0.981674   -0.95745366 -0.92347268
#  -0.88007748 -0.82771044 -0.76690542 -0.69828229 -0.6225406  -0.54045251
#  -0.45285485 -0.36064061 -0.26474988 -0.16616018 -0.06587659  0.03507857
#   0.13567613  0.23489055  0.33171042  0.4251487   0.51425287  0.59811455
#   0.67587883  0.74675295  0.8100144   0.86501827  0.91120382  0.94810022
#   0.97533134  0.99261957  0.99978867  0.99676556  0.98358105  0.96036956
#   0.9273677   0.88491192  0.83343502  0.77346177  0.70560358  0.63055219
#   0.54907273  0.46199582  0.37020915  0.27464844  0.17628785  0.07613012
# ...

# %%
# lets try to plot this
# plotting the Data

# %%
# sine wave
plt.plot(x,y)
plt.grid()

# %%
# Cosine Wave
plt.plot(x,z)
plt.grid()

# %%
# Just add title, x-axis & y-axis labels
plt.figure(figsize=(10,10))
plt.plot(x,y)
plt.xlabel('Angle')
plt.ylabel('Sine Value')
plt.title('Sine Wave')
plt.grid()

# %%
# Just add title, x-axis & y-axis labels
plt.figure(figsize=(10,10))
plt.plot(x,y)
plt.xlabel('Angle')
plt.ylabel('Cosine Value')
plt.title('Cosine Wave')
plt.grid()

# %%
# lets see Parabola Plot
x = np.linspace(-10,10,20)
y = x**2
plt.plot(x,y)
plt.grid()
plt.show()

# %%
# plot in different colors and Symbols
plt.plot(x,y,'r+')

# %%
plt.plot(x,y,'g.')

# %%
plt.plot(x,y,'rx')
plt.show()

# %%
# how you can plot multiple lines in a single graph
x = np.linspace(-5,5,50)
y = np.sin(x)
z = np.cos(x)
plt.figure(figsize=(10,10))
plt.plot(x,y,'g-')
plt.plot(x,z,'r--')
plt.grid()
plt.show()

# %%
# Bar plot

# %%
# we use this, when we need to plot a blank  plot
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax
# Out:
# <Axes:>

# %%
fig = plt.figure() #this will create empty plot
# and in that empty plot will do several things
# 'ax' is nothing but their axes
ax = fig.add_axes([0,0,1,1])
# this will enclose our plot in a rectangle
# 0,0 - is the origin
# 1,1 - height and width of the rectangle
languages=['English','French','Spanish','Latin','Germany']
people = [100,50,150,40,70]
ax.bar(languages,people)
plt.xlabel('People Speaking languages')
plt.ylabel('no. of people')
plt.title("Bar Plot")
plt.grid()
plt.show()

# %% [markdown]
# Pie chart

# %%
fig = plt.figure() #this will create empty plot
# and in that empty plot will do several things
# 'ax' is nothing but their axes
ax = fig.add_axes([0,0,1,1])
# this will enclose our plot in a rectangle
# 0,0 - is the origin
# 1,1 - height and width of the rectangle
languages=['English','French','Spanish','Latin','Germany']
people = [100,50,150,40,70]
ax.pie(people,labels=languages,autopct='%1.2f%%')
plt.show()

# %% [markdown]
# Scatter Plot

# %%
x=np.linspace(0,10,30)
y=np.sin(x)
z=np.cos(x)
fig =plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.scatter(x,y,color='g')
ax.scatter(x,z,color='b')
plt.show()

# %% [markdown]
# lets see, how we can build 3D plot
#
# 3D Scatter Plot

# %%
# as this is 3d plot, will be using 3 axes - x,y,z 
fig=plt.figure()
ax=plt.axes(projection='3d')
z=20 * np.random.random(100)
x=np.sin(z)
y=np.cos(z)
ax.scatter(x,y,c=z,cmap='Blues')
plt.show()

# %%
# trying by changing the variable name
# as this is 3d plot, will be using 3 axes - x,y,z 
fig=plt.figure()
ax=plt.axes(projection='3d')
a=20 * np.random.random(100)
b=np.sin(a)
c=np.cos(a)
ax.scatter(a,b,c,cmap='Blues')
plt.show()

# %%
# trying by changing the variable name
# as this is 3d plot, will be using 3 axes - x,y,z 
fig=plt.figure()
ax=plt.axes(projection='3d')
a=20 * np.random.random(100)
b1=np.sin(a)
b2=np.cos(a)
ax.scatter(b1,b2,c=a,cmap='Blues')
plt.show()

# %% [markdown]
# ### Seaborn
#
#  - Data Visualization Library

# %%
# importing ther library 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Note: Seaborn has some built-in Datasets, these are some basic Machine Learning Datasets.

# %%
# total bill vs tip dataset
tips = sns.load_dataset('tips')

# %%
# changing the variable name
df=tips

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# setting a theme for the plots
sns.set()

# %%
# Visualize the data
# relative plot
sns.relplot(data = df, x = 'total_bill',y='tip',col='time',
           hue='smoker',style='smoker',size='size')

# %%
# loading the iris Dataset 
iris = sns.load_dataset('iris')

# %%
# changing the variable name 
df=iris

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Scatter Plot

# %%
sns.scatterplot(x='sepal_length',y='petal_length',hue='species',data=df)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(x='sepal_length',y='petal_width',hue='species',data=df)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
# loading the titanic the dataset
ti=sns.load_dataset('titanic')

# %%
ti.head()
# 0-dead
# 1-survive
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
ti['survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %% [markdown]
# Count plot On titanic dataset

# %%
ti.shape
# Out:
# (891, 15)

# %%
# no. of people in third,second and first
sns.countplot(x='class',data=ti)
plt.grid()

# %%
ti['class'].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %%
sns.countplot(x='survived',data=ti)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %%
sns.countplot(x='survived',hue='class',data=ti)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='count'>

# %% [markdown]
# Bar chart

# %%
sns.barplot(x='sex',y='survived',hue='class',data=ti)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='survived'>

# %%
conda install scikit-learn=
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# house price dataset
# this dataset is not available in seaborn 
# So, will import it through sklearn
# from sklearn import datasets
from sklearn.datasets import load_boston
# import numpy as np
# from sklearn.datasets import fetch_california_housing
# housing = fetch_california_housing()

# %%
import pandas as pd

# %%
house_boston=load_boston()

# %%
print(house_boston)
# this house boston Dataset is in array format 
# so to convertit into Dataframe we used Pandas Data Frame
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]]), 'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
# ...

# %%
a=pd.DataFrame(house_boston.data,columns=house_boston.feature_names)

# %%
a.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
# adding a Price Column
a['Price'] = house_boston.target

# %%
a.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %% [markdown]
# Distribution Plot
#  - Distribution Plot: will tells us in what range most value lies.

# %%
sns.displot(a['Price'])

# %%
a.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %% [markdown]
# Correlation: Basically there are two types of Correlation.
#
# 1.Postive Correlation
#
# 2.Negative Correlation
#
# See, there are total 14 columns. and if i talk correlation between these two columns like crime rate and price. These both are negatively correlated, because, if the crime rate increases the rate of price decreases.
#
# Negative Correlation: if one variable increases and another one variable decreases - then Negative Correlation
#
# Positive Correlation: if one variable increases and another one also increases then it is said to be - Positive Correlation.
#
# Postive Correlation examples: If the number of rooms increases then the price will also increases. In this case, no. of rooms and Price are Positively Correlated.
#
# Negative Correlation: In Case of Crime and Price both these are Negatively Correlated.

# %% [markdown]
# # Heat Map
# Constructing the Heat MAp

# %%
# before this will find the correlation 
cor=a.corr()
cor
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
# Constructing a Heat Map
plt.figure(figsize=(10,10))
sns.heatmap(cor,cbar=True, square=True,fmt='.1f',annot=True,
            annot_kws={'size':8}, cmap="Blues")
# Out:
# <AxesSubplot:>
