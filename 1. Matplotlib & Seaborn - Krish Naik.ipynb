# %% [markdown]
# #### Matplotlib Tutorial
#  - Matplotlib is a plotting Library for the Python Programming language and its numerical mathematics extension Numpy. It provides an Object-Oriented API for embedding plots into applications using general-purpose GUI toolkits like Tkinter, wxPython, QT, or GTK+

# %% [markdown]
# Some of the major Pros of Matplotlib are:
#  - Generally weasy to  get started for simple plots
#  - Supports for customs labels and texts
#  - Great control of every elements in a figure
#  - High Quality output in many formats
#  - Very Customizablein General

# %%
# in order to import matplotlib will basically write the below query
# "matplotlib.pyplot" is the library will basically use.
import matplotlib.pyplot as plt
# when specifically when you're working with Jupyter, 
# we specifically write the below line
# %matplotlib inline
# by writing the above query, we didnt have to wtrite the plt.show()
# otherwise if i did not write "%matplotlib inline", i have to always write 
# plt.show() to display the graph

# %%
import numpy as np

# %%
# simple examples
x=np.arange(0,10)
y=np.arange(11,21)

# %%
a=np.arange(40,50)
b=np.arange(50,60)

# %% [markdown]
# ###### Scatter plot

# %%
# plotting using matplotlib
# scatter plot
# is used scatter the value of x and y
plt.scatter(x,y,c='r')

# %%
# will put some "x" and "y" title 
plt.scatter(x,y,c='r')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2D')
# Out:
# Text(0.5, 1.0, 'Graph in 2D')

# %%
# if you want  to save the above image 
plt.savefig('scatter1.png')

# %% [markdown]
# ###### Plot

# %%
y=x*x

# %%
# now, another function in matplotlib is "plot"
# in plot, you'll be specifically gettong a straight line 
plt.plot(x,y)

# %%
# 3rd parameter is color 
plt.plot(x,y,'r')

# %%
# double dashed
plt.plot(x,y,'r--')

# %%
plt.plot(x,y,'r*-')

# %%
plt.plot(x,y,'ro')

# %%
plt.plot(x,y,'ro-')

# %%
plt.plot(x,y,'ro--')

# %%
plt.plot(x,y,'r*')

# %%
plt.plot(x,y,'r2')

# %%
plt.plot(x,y,'r3')

# %%
plt.plot(x,y,'ro--',linestyle='dashed',linewidth=2, markersize=12)

# %%
plt.plot(x,y,'r*',linestyle='dashed',linewidth=2, markersize=12)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('2D Diargram')
# Out:
# Text(0.5, 1.0, '2D Diargram')

# %% [markdown]
# ###### creating subplot

# %%
# first row first column
plt.subplot(2,2,1)
plt.plot(x,y,'r--')
# first row second column
plt.subplot(2,2,2)
plt.plot(x,y,'b*-')
# second row first column
plt.subplot(2,2,3)
plt.plot(x,y,'go')
# second row second column
plt.subplot(2,2,4)
plt.plot(x,y,'yo--')
# And always remember as we hvae given 2 row, 2 columns will just have 4 positions

# %%
x=np.arange(1,11)
y= 3*x+5
plt.title("Matplotlib Demo")
plt.xlabel("X axis caption")
plt.ylabel("Y axis caption")
plt.plot(x,y)

# %%
plt.show()

# %%
np.pi
# Out:
# 3.141592653589793

# %%
# compute the x and y coordinates for points on a sine curve 
x = np.arange(0,4*np.pi,0.1)
y = np.sin(x)
plt.title("sine wave form")

# Plot the points using matplotlib
plt.plot(x,y)

# %%
# Subplot()
# Compute the x and y coordinates for points on sine and cosine curves
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0, 5*np.pi,0.1)
ysin = np.sin(x)
ycos = np.cos(x)

# set up a subplot grid that has height 2 and width 1,
# and set the first such subplot as active.
plt.subplot(2,1,1)

# make the first plot
plt.plot(x,ysin,'r--')
plt.title('Sine')

# Set the second subplot as active, and make the second plot.
plt.subplot(2,1,2)
plt.plot(x,ycos,'g--')
plt.title('Cosine')

# show the figure
plt.show()

# %% [markdown]
# ###### Bar plot

# %%
# bar plot
x=[2,8,10]
y=[11,16,9]

x2=[3,9,11]
y2=[6,15,7]

plt.bar(x,y,align='center')
plt.bar(x2,y2,color='g')
plt.title("Bar Graph")
plt.ylabel('Y axis')
plt.xlabel('X axis')

plt.show()

# %% [markdown]
# #### Histogram

# %%
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
plt.hist(a,bins=10)
plt.title('Histogram')
plt.show()

# %% [markdown]
# #### Box Plot Using Matplotlib

# %%
data = [np.random.normal(0,std,100) for std in range(1,4)]

# %%
# rectangular box plot
# plt.figure(figsize=10,10)
plt.boxplot(data,vert=True,patch_artist=True);
# if patch_artist = true then color will be there 
# if path_artist = false there will no color
# and if the vert = false then it will plot the box plot  horizontally
plt.grid()

# %%
# rectangular box plot
# plt.figure(figsize=10,10)
plt.boxplot(data,vert=False,patch_artist=False);
# if patch_artist = true then color will be there 
# if path_artist = false there will no color
# and if the vert = false then it will plot the box plot  horizontally
plt.grid()

# %%
data
# Out:
# [array([-0.38851638, -1.25436324, -0.27946344, -0.88528254, -1.23423984,
#         -1.55253417,  0.16676432,  1.04691611,  0.48597254,  1.36904149,
#         -0.40312983,  1.43835926, -1.35776301,  0.78209745, -1.02906495,
#          0.17627208,  0.71817482, -0.04217412,  1.12566924,  0.1705145 ,
#         -0.08653853, -1.54951344,  0.92019185,  0.02195508, -0.2003826 ,
#         -0.4490244 , -0.12283571,  1.08082001,  0.0749665 ,  0.06242055,
#         -0.01906727, -0.79736633,  0.66578797,  1.26792272, -0.24967493,
#         -0.9134844 ,  0.14639135,  0.6952905 ,  1.82632356,  0.61845765,
#          0.62278449,  0.92276093,  0.25561493, -0.01831844,  1.28053832,
#          0.00838824, -1.02970746, -0.0485214 , -0.18571513,  0.18227803,
#          1.15481572, -0.24908154, -1.21681963,  1.15398547,  0.05153303,
#          0.83270504,  0.90476584, -0.41279794, -0.28379606,  0.85769648,
#         -0.0844878 , -1.42041263,  0.80153688, -1.6733039 ,  1.14303844,
# ...

# %% [markdown]
# #### Pie chart

# %%
#  data to plot
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215,130,245,210]
colors = ['gold','yellowgreen','lightcoral','lightskyblue']
explode = (0.1,0,0,0) #explode


# plot
plt.pie(sizes,explode=explode, labels=labels,
        colors=colors,autopct='%1.1f%%', shadow=True
       )


plt.axis('equal')
plt.show()

# %% [markdown]
# # -------------------------XXXX---------------------------
# ## Part 1.  Seaborn
# ### Seaborn Tutorial
# ### All the Plotting are done for Continuous Features
# #### Distribution plots
#  - distplot
#  - joinplot
#  - pairplot
#
# Practise probelm on IRIS Dataset

# %%
import seaborn as sns
import numpy as np
import pandas as pd

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# here the tip column is the target column or dependent column 
# and rest others are independent columns or input features or x
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %% [markdown]
# ### Correlation with Heatmap
#  - A correlation heatmap uses coloured cells, typically in a monochromatic scale, to show a 2D correlation matrix (table) between two discrete dimensionsor evevnt types. it is very important in Future Selection
# ### Seaborn has property called as Heatmap, which helps us to find out the Correlation between each  and every feature
#  - Correlation helps us to find out the inter-relationship between all the features
#  - suppose we have to find out correlationship between:
#    - total bill and tip
#    - sex and smokers
#  - this correlationship will be only find out when your value is either float or integer
#  - if your value is categorical(string) in feature, you'll be not be able to find out the correlationship
#  - because categoriacl features are objects types, where as other features are float and integer type.
#  - whenever we are applying correlation, your value will be ranging from -1 to 1, and thati sspefically called as Pearson Correlation.

# %%
# univariatte - one feature or you can also take 2 features
# Bivariate() - 2 features means 2d diagram means joinplot
# more than 2 features - pairplot()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
df.corr()
# here we are getting three features because 
# it has float or integer datatype
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
# checking the datatypoe of the features
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %% [markdown]
# ###### heatmap

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())

# %% [markdown]
# #### Join Plot
# A join plot allows to study the relationship between 2 numeric variables(2 numerics datatype features). The central chart display correlation. it is usually a scatterplot, a hexbin plot, a 2D Histogram or a 2D density plot
#
# Jopinplot: It actually helps you to do univariate analysis and when i say univariate again here we are taking 2 features, so we can also Bivariate analysis
#
# But make sure that you just have 2 features while working with joinplot.

# %% [markdown]
# #### Univariate Analysis

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.jointplot(x="tip",y="total_bill",data=df, kind='hex')

# %%
sns.jointplot(x="tip",y="total_bill",data=df, kind='reg')

# %% [markdown]
# #### Note: Above plot can be called as a Bivariatre Analysis because we have used 2 features
#
# #### Now, if your features are more than 2, then will use Pair plot
#
# ### Pair plot
#  - A "Pair Plot" is also known as Scatter Plot, in which one variabble in the same data row is matched with another variables's value, like this: Pairs plots are just elaborations on this, showing all variables paired with all other variables.
#  - In Pair plot, it will do Permutation and Combination of all the features and alway remember that when you are plotting this Pair plot, the features need to be of float or integer value

# %%
sns.pairplot(df)

# %%
# All the points which are plotted is based on the sex features.
# where blue is male
# orange is female
sns.pairplot(df,hue='sex')

# %%
df['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
# will try using "smoker" feature 
# smoker or non-smoker
sns.pairplot(df,hue='smoker')

# %% [markdown]
# #### Dist Plot
#  - Dist Plot helps us to check the distribution of the columns feature

# %%
sns.distplot(df['tip'])
# by default kde is True, So you're getting diagram.
# and when is kde is True, y axis get into percentage

# %%
sns.distplot(df['tip'],kde=False,bins=10)

# %% [markdown]
# ### Part 2. Seaborn
# ## Categorical Plots
# Seaborn also helps us in doing the analysis on Categorical features Data points. In this Section we will discuss about
#  - boxplot
#  - violinplot
#  - countplot
#  - bas plot

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# count plot
sns.countplot('sex',data=df)

# %%
sns.countplot('smoker',data=df)

# %%
sns.countplot('time',data=df)

# %%
sns.countplot('day',data=df)

# %%
#  you can change the "x" and "y" axis position
sns.countplot(y='day',data=df)

# %%
#  you can change the "x" and "y" axis position
sns.countplot(y='sex',data=df)

# %%
# Bar plot
# bar plot does also the same thing 
# but we have to gove both "x and y " value
sns.barplot(x='total_bill',y='sex',data=df)

# %%
sns.barplot(y='total_bill',x='smoker',data=df)

# %%
sns.barplot(x='sex',y='total_bill',data=df)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Box Plot
# A Box and whisker plot (sometimes called a boxplot) is a graph that presents information fromm a five-number summary.

# %%
sns.boxplot('smoker','total_bill',data=df)

# %%
sns.boxplot('sex','total_bill',data=df)

# %%
sns.boxplot(x='day',y="total_bill",data=df)

# %%
# adding different color
sns.boxplot(x='day',y="total_bill",data=df,palette='rainbow')

# %%
# to consider all the features
sns.boxplot(data=df,orient='v')

# %%
# categories my data based on some other categories

sns.boxplot(x='total_bill',y='day',hue='smoker',data=df)

# %%
sns.boxplot(x='total_bill',y='day',hue='sex',data=df)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Violin plot
# Violin plot helps us to see both the distributor of data in terms of Kernel density estimation and the box plot

# %%
sns.violinplot(x='total_bill',y='day',data=df)

# %%
# Practise Homework
iris = sns.load_dataset('iris')
